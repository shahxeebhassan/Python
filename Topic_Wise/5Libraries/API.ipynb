# %%
import requests
import json

response = requests.get('https://itunes.apple.com/search?entity=movie&term=artificial+intelligence')
# print(json.dumps(response.json(), indent=2))
o = response.json()

for i in o['results']:
    print(i['trackName'])
# Out:
# A.I. Artificial Intelligence
